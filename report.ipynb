# %% [markdown]
# Метрики моделей:

# %% [markdown]
# Метрики Confusion Matrix:

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-3.png](attachment:image-3.png) ![image-4.png](attachment:image-4.png) ![image-5.png](attachment:image-5.png)

# %% [markdown]
# Классические модели метрики на тесте:

# %%
'''
Model,Accuracy,Precision,Recall,F1,ROC AUC,pr_auc
LogReg,0.78,0.777,0.683,0.727,0.833,0.821
RF,0.789,0.78,0.709,0.743,0.827,0.824
GB,0.735,0.861,0.456,0.596,0.791,0.795
LGB,0.762,0.768,0.639,0.698,0.818,0.811
XGB,0.789,0.826,0.645,0.724,0.825,0.822
'''

# %% [markdown]
# ![image-2.png](attachment:image-2.png)![image.png](attachment:image.png)

# %% [markdown]
# Классические модели метрики на валидации:

# %%
'''
Model,Accuracy,Precision,Recall,F1,ROC AUC,pr_auc
LogReg,0.767,0.774,0.645,0.704,0.828,0.818
RF,0.751,0.744,0.641,0.689,0.798,0.79
GB,0.713,0.824,0.422,0.558,0.764,0.765
LGB,0.739,0.743,0.598,0.663,0.799,0.785
XGB,0.754,0.801,0.567,0.664,0.806,0.797
'''

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Нейроная модель метрики на тесте:
#
# Epoch 10/50, Loss: 0.5438
#
# Epoch 20/50, Loss: 0.3613
#
# Epoch 30/50, Loss: 0.2864
#
# Epoch 40/50, Loss: 0.2479
#
# Epoch 50/50, Loss: 0.2247

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png) ![image-4.png](attachment:image-4.png) ![image-4.png](attachment:image-5.png)
